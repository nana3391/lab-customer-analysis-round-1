# %%
import pandas as pd  # keywords are highlighted in green, other strings in red, etc.
import numpy as np

# %%
# Reading data into a DataFrame
file1 = pd.read_csv('file1.csv')
display(file1.head(10))
display(file1.tail())
file1.shape
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
# 5  OC83172      Oregon      F              Bachelor              825629.78%
# 6  XZ87318      Oregon      F               College              538089.86%
# 7  CF85061     Arizona      M                Master              721610.03%
# 8  DY87989      Oregon      M              Bachelor             2412750.40%
# 9  BQ94931      Oregon      F               College              738817.81%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# ...

# %%
file1["Customer Lifetime Value"]=file1["Customer Lifetime Value"].str.replace("%","")
file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                  697953.59      0.0                  94.0
# 2                 1288743.17  48767.0                 108.0
# ...

# %%
file1["Customer Lifetime Value"]=pd.to_numeric(file1["Customer Lifetime Value"], errors='coerce')/100
file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                         NaN      0.0                1000.0
# 1                   6979.5359      0.0                  94.0
# 2                  12887.4317  48767.0                 108.0
# ...

# %%
# Reading data into a DataFrame
file2 = pd.read_csv('file2.csv')
display(file2.head(10))
display(file2.tail())
file2.shape
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
# 5  WL99637     Arizona      M  Bachelor              761413.80%   27293
# 6  UC84059  California      F    Master              689845.53%   70950
# 7  HW62747      Oregon      M   College              229837.92%       0
# 8  BH11344      Oregon      F    Doctor              280669.61%   37009
# 9  TX28465      Nevada      M   College              520611.82%   52629
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00          633.600000
# ...

# %%
file2["Customer Lifetime Value"]=file2["Customer Lifetime Value"].str.replace("%","")
file2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor               323912.47   16061
# 1    CW49887  California      F    Master               462680.11   79487
# 2    MY31220  California      F   College               899704.02   54230
# 3    UH35128      Oregon      F   College              2580706.30   71210
# 4    WH52799     Arizona      F   College               380812.21   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master               847141.75   63513
# 992  BS91566     Arizona      F   College               543121.91   58161
# 993  IL40123      Nevada      F   College               568964.41   83640
# 994  MY32149  California      F    Master               368672.38       0
# 995  SA91515  California      M  Bachelor               399258.39       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
file2["Customer Lifetime Value"]=pd.to_numeric(file2["Customer Lifetime Value"], errors='coerce')/100
file2
# Out:
#     Customer          ST GENDER Education  Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor                3239.1247   16061
# 1    CW49887  California      F    Master                4626.8011   79487
# 2    MY31220  California      F   College                8997.0402   54230
# 3    UH35128      Oregon      F   College               25807.0630   71210
# 4    WH52799     Arizona      F   College                3808.1221   94903
# ..       ...         ...    ...       ...                      ...     ...
# 991  HV85198     Arizona      M    Master                8471.4175   63513
# 992  BS91566     Arizona      F   College                5431.2191   58161
# 993  IL40123      Nevada      F   College                5689.6441   83640
# 994  MY32149  California      F    Master                3686.7238       0
# 995  SA91515  California      M  Bachelor                3992.5839       0
#
# ...

# %% [markdown]
# # Show the DataFrame's shape.

# %%
# Reading data into a DataFrame
file3 = pd.read_csv('file3.csv')
display(file3.head(10))
display(file3.tail())
file3.shape
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
# 5  VI78454     Arizona              2750.705045               College      M
# 6  FP59138      Oregon             13024.130120                Master      M
# 7  XN62489      Oregon              2538.626320              Bachelor      M
# 8  GP66031  California              2585.955652               College      F
# 9  IX68587      Nevada              5096.673223                Master      F
#
#    Income  Monthly Premium Auto  Number of Open Complaints     Policy Type  \
# ...

# %%
file3.dtypes
# Out:
# Customer                      object
# State                         object
# Customer Lifetime Value      float64
# Education                     object
# Gender                        object
# Income                         int64
# Monthly Premium Auto           int64
# Number of Open Complaints      int64
# Policy Type                   object
# Total Claim Amount           float64
# Vehicle Class                 object
# dtype: object

# %%
file3 = file3.drop(['Education','Number of Open Complaints'], axis=1)
file3.head()
# Out:
#   Customer       State  Customer Lifetime Value Gender  Income  \
# 0  SA25987  Washington              3479.137523      M       0
# 1  TB86706     Arizona              2502.637401      M       0
# 2  ZL73902      Nevada              3265.156348      F   25820
# 3  KX23516  California              4455.843406      F       0
# 4  FN77294  California              7704.958480      M   30366
#
#    Monthly Premium Auto    Policy Type  Total Claim Amount  Vehicle Class
# 0                   104  Personal Auto          499.200000   Two-Door Car
# 1                    66  Personal Auto            3.468912   Two-Door Car
# 2                    82  Personal Auto          393.600000  Four-Door Car
# 3                   121  Personal Auto          699.615192            SUV
# 4                   101  Personal Auto          484.800000            SUV

# %%
file3.duplicated()
file3
# Out:
#      Customer       State  Customer Lifetime Value Gender  Income  \
# 0     SA25987  Washington              3479.137523      M       0
# 1     TB86706     Arizona              2502.637401      M       0
# 2     ZL73902      Nevada              3265.156348      F   25820
# 3     KX23516  California              4455.843406      F       0
# 4     FN77294  California              7704.958480      M   30366
# ...       ...         ...                      ...    ...     ...
# 7065  LA72316  California             23405.987980      M   71941
# 7066  PK87824  California              3096.511217      F   21604
# 7067  TD14365  California              8163.890428      M       0
# 7068  UP19263  California              7524.442436      M   21941
# 7069  Y167826  California              2611.836866      M       0
#
#       Monthly Premium Auto     Policy Type  Total Claim Amount  Vehicle Class
# 0                      104   Personal Auto          499.200000   Two-Door Car
# ...

# %%
file3.drop_duplicates( subset=None, keep="first", inplace=False)
# Out:
#      Customer       State  Customer Lifetime Value Gender  Income  \
# 0     SA25987  Washington              3479.137523      M       0
# 1     TB86706     Arizona              2502.637401      M       0
# 2     ZL73902      Nevada              3265.156348      F   25820
# 3     KX23516  California              4455.843406      F       0
# 4     FN77294  California              7704.958480      M   30366
# ...       ...         ...                      ...    ...     ...
# 7065  LA72316  California             23405.987980      M   71941
# 7066  PK87824  California              3096.511217      F   21604
# 7067  TD14365  California              8163.890428      M       0
# 7068  UP19263  California              7524.442436      M   21941
# 7069  Y167826  California              2611.836866      M       0
#
#       Monthly Premium Auto     Policy Type  Total Claim Amount  Vehicle Class
# 0                      104   Personal Auto          499.200000   Two-Door Car
# ...

# %%
filtered_df = file3[file3['Income'] > 0]
filtered_df= file3
file3
# Out:
#      Customer       State  Customer Lifetime Value Gender  Income  \
# 0     SA25987  Washington              3479.137523      M       0
# 1     TB86706     Arizona              2502.637401      M       0
# 2     ZL73902      Nevada              3265.156348      F   25820
# 3     KX23516  California              4455.843406      F       0
# 4     FN77294  California              7704.958480      M   30366
# ...       ...         ...                      ...    ...     ...
# 7065  LA72316  California             23405.987980      M   71941
# 7066  PK87824  California              3096.511217      F   21604
# 7067  TD14365  California              8163.890428      M       0
# 7068  UP19263  California              7524.442436      M   21941
# 7069  Y167826  California              2611.836866      M       0
#
#       Monthly Premium Auto     Policy Type  Total Claim Amount  Vehicle Class
# 0                      104   Personal Auto          499.200000   Two-Door Car
# ...
